# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia340rori2025/Crime_Data_from_2020_to_Present.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
df.shape #show the number of rows and columns
# Out:
# (1004991, 28)

# %%
df.describe() #statistical summary of the data
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06
# mean   2.202215e+08  1.339900e+03  1.069174e+01  1.115633e+03  1.400348e+00
# std    1.319718e+07  6.510613e+02  6.110255e+00  6.111605e+02  4.899691e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209159e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311103e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.004991e+06  1.004991e+06  1.004975e+06   327247.000000  1.004980e+06
# mean   5.001568e+02  2.891706e+01  3.056201e+02      363.955300  4.999174e+02
# ...

# %%
df['date occurred'] = pd.to_datetime(df['Date Rptd']) #chnage the data type to date with specific format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 29 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
# ...

# %%
df.info() #shows the data types and number of null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 29 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
# ...

# %%
#rename columns
df = df.rename(columns={"TIME OCC" : "time occurred", "DATE OCC" : "date occurred", "Weapon Desc" : "description of weapon"})
df.head
# Out:
# <bound method NDFrame.head of              DR_NO               Date Rptd           date occurred  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM
# 3        210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM
# ...            ...                     ...                     ...
# 1004986  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM
# 1004987  250404100  02/18/2025 12:00:00 AM  02/18/2025 12:00:00 AM
# 1004988  251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM
# 1004989  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM
# 1004990  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM
#
#          time occurred  AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
df.isnull().sum()
# Out:
# DR_NO                          0
# Date Rptd                      0
# date occurred                  0
# time occurred                  0
# AREA                           0
# AREA NAME                      0
# Rpt Dist No                    0
# Part 1-2                       0
# Crm Cd                         0
# Crm Cd Desc                    0
# Mocodes                   151619
# Vict Age                       0
# Vict Sex                  144644
# Vict Descent              144656
# Premis Cd                     16
# Premis Desc                  588
# Weapon Used Cd            677744
# description of weapon     677744
# Status                         1
# Status Desc                    0
# Crm Cd 1                      11
# Crm Cd 2                  935831
# Crm Cd 3                 1002677
# Crm Cd 4                 1004927
# LOCATION                       0
# Cross Street              850755
# LAT                            0
# LON                            0
# ...

# %%
df['AREA NAME'] #select and display a column
# Out:
# 0          N Hollywood
# 1          N Hollywood
# 2             Van Nuys
# 3             Wilshire
# 4              Pacific
#               ...
# 1004986        Topanga
# 1004987     Hollenbeck
# 1004988         Newton
# 1004989     Devonshire
# 1004990        Mission
# Name: AREA NAME, Length: 1004991, dtype: object

# %%
df.sort_values(by='Vict Sex') #sort rows by a column
# Out:
#              DR_NO               Date Rptd           date occurred  \
# 807776   232012240  06/29/2023 12:00:00 AM  06/29/2023 12:00:00 AM
# 1004990  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM
# 740998   231116367  12/02/2023 12:00:00 AM  11/29/2023 12:00:00 AM
# 740999   232013619  07/26/2023 12:00:00 AM  07/25/2023 12:00:00 AM
# 361524   210208783  04/29/2021 12:00:00 AM  04/29/2021 12:00:00 AM
# ...            ...                     ...                     ...
# 1004944  251204103  01/22/2025 12:00:00 AM  01/21/2025 12:00:00 AM
# 1004958  250300002  02/26/2025 12:00:00 AM  02/25/2025 12:00:00 AM
# 1004967       2503  03/10/2025 12:00:00 AM  03/06/2025 12:00:00 AM
# 1004980  250304234  03/01/2025 12:00:00 AM  02/19/2025 12:00:00 AM
# 1004983  250304291  04/29/2025 12:00:00 AM  04/29/2025 12:00:00 AM
#
#          time occurred  AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 807776            2115    20      Olympic         2091         2     740
# ...

# %%
df[0:10] #slice by rows
# Out:
#        DR_NO               Date Rptd           date occurred  time occurred  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM            845
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM           1845
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM           1240
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM           1310
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM           1830
# 5  240412063  12/11/2024 12:00:00 AM  11/11/2020 12:00:00 AM           1210
# 6  240317069  12/16/2024 12:00:00 AM  04/16/2020 12:00:00 AM           1350
# 7  201115217  10/29/2020 12:00:00 AM  07/07/2020 12:00:00 AM           1400
# 8  241708596  04/20/2024 12:00:00 AM  03/02/2020 12:00:00 AM           1200
# 9  242113813  12/18/2024 12:00:00 AM  09/01/2020 12:00:00 AM            900
#
#    AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    15  N Hollywood         1502         2     354
# ...

# %%
df[df['time occurred']>5] # select rows by values
# Out:
#              DR_NO               Date Rptd           date occurred  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM
# 3        210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM
# ...            ...                     ...                     ...
# 1004986  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM
# 1004987  250404100  02/18/2025 12:00:00 AM  02/18/2025 12:00:00 AM
# 1004988  251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM
# 1004989  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM
# 1004990  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM
#
#          time occurred  AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0                  845    15  N Hollywood         1502         2     354
# ...

# %% [markdown]
# You need to define the conditions in filtering data, such as:
#
# ```df = df[(df['deaths']>=0) & (df['cases']>=0) & (df['cum']>=0)] #filter data```
#
# In your code, you only listed the column names; no conditions
#
# If you want to select the columns instead of filtering, you should use this example:
#
# ```df = df[['country','cases','deaths','pop','cum','date']] # keep specific columns ```

# %%
df = df[['AREA NAME','AREA','time occurred','Crm Cd','Part 1-2','date occurred']] # keep specific columns

# %%
sum_victims_by_area = df.groupby('AREA NAME')['Vict Sex'].count() # calculate the total number of victims per area
sum_victims_by_area.plot.bar() # use a bar chart to show the results of the total number of victims per area

sum_gender_by_area= df.groupby('Vict Sex')['AREA NAME'].sum()

# %%
In the following code, there is no `sum_gender_by_area` defined. 

You need to either use an aggregation function to calculate the ```sum_gender_by_area```, such as:

```sum_gender_by_area= df.groupby('Vict Sex')['AREA NAME'].sum()```

or use the existing ```sum_victims_by_area``` to plot

# %%
```sum_gender_by_area= df.groupby('Vict Sex')['AREA NAME'].sum()```

# %% [markdown]
# A) VIEWING THE DATA: I have 5 rows and 28 columns of data for crime in 2020, ranging from; date reported, victim sex, victim age, time occuring, etc.
#
# B)CLEAN THE DATA: Did not need to handle missing values as it would've deleted my data. I renamed the time occurred, date occurred, and description of weapon to make it easier to read
#
# C) I grouped the data by area and victim sex, sorted my rows by the time occurring for crime, and selected and displayed my data by shwoing preicse times and locations for where and when the crimes occurred in the year 2020.
#
# D)
# LINE GRAPH: I edited the code to try and make my line graph work but I was not able to acccess it. The intial plan was to show the total number of victims per area of crime in the year 2020.
#
# BAR GRAPH:The bar graph shows the different areas where crimes occurred and the total number of victims by sex in each area shown. the highest value on the chart is above 60,000 in Central while the lowest is aroud 27,000 in Foothill.
